# %% [markdown]
# <a href="https://colab.research.google.com/github/NehalShahu/NNDL_practicals/blob/main/NNDL_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

print('Libraries imported successfully.')
# Out:
# Libraries imported successfully.

# %% [markdown]
# ## Load Dataset
#
# ### Subtask:
# Load the MNIST handwritten digit dataset, splitting it into training and testing sets.

# %% [markdown]
# **Reasoning**:
# As per the instructions, the first step is to load the MNIST dataset and split it into training and testing sets.

# %%
print('Loading MNIST dataset...')
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
print('MNIST dataset loaded successfully.')
# Out:
# Loading MNIST dataset...
# MNIST dataset loaded successfully.

# %% [markdown]
# ## Display Sample Sizes
#
# ### Subtask:
# Show the shapes of the loaded datasets and display a sample image with its label.

# %% [markdown]
# **Reasoning**:
# To understand the structure of the loaded datasets, I will print the shapes of `x_train`, `y_train`, `x_test`, and `y_test`.

# %%
print(f"Shape of x_train: {x_train.shape}")
print(f"Shape of y_train: {y_train.shape}")
print(f"Shape of x_test: {x_test.shape}")
print(f"Shape of y_test: {y_test.shape}")
# Out:
# Shape of x_train: (60000, 28, 28)
# Shape of y_train: (60000,)
# Shape of x_test: (10000, 28, 28)
# Shape of y_test: (10000,)

# %% [markdown]
# **Reasoning**:
# To complete the subtask, I need to display a sample image and its label. I will use `matplotlib.pyplot` to show the image and print the corresponding label.

# %%
plt.figure(figsize=(2, 2))
plt.imshow(x_train[0], cmap=plt.cm.binary)
plt.title(f"Label: {y_train[0]}")
plt.axis('off')
plt.show()

# %% [markdown]
# ## Normalize Pixel Values
#
# ### Subtask:
# Normalize the pixel values of the image data to a range between 0 and 1.

# %% [markdown]
# **Reasoning**:
# Convert the training and testing image data to floating-point numbers and normalize their pixel values to a range between 0 and 1. Then, print the shapes and data types to verify the changes.

# %%
print('Normalizing pixel values...')
x_train_normalized = x_train.astype('float32') / 255.0
x_test_normalized = x_test.astype('float32') / 255.0

print(f"Shape of x_train_normalized: {x_train_normalized.shape}, dtype: {x_train_normalized.dtype}")
print(f"Shape of x_test_normalized: {x_test_normalized.shape}, dtype: {x_test_normalized.dtype}")
print('Pixel values normalized successfully.')
# Out:
# Normalizing pixel values...
# Shape of x_train_normalized: (60000, 28, 28), dtype: float32
# Shape of x_test_normalized: (10000, 28, 28), dtype: float32
# Pixel values normalized successfully.

# %% [markdown]
# ## Design Neural Network
#
# ### Subtask:
# Design the Feed-Forward Neural Network model using Keras Sequential API, including Flatten, Dense (ReLU), and Dense (Softmax) layers.

# %% [markdown]
# **Reasoning**:
# As per the instructions, I need to import the required layers and then define the Sequential model with Flatten, Dense (ReLU), and Dense (Softmax) layers.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense

print('Designing the neural network model...')

model = Sequential([
    Flatten(input_shape=(28, 28)), # Input layer: Flattens the 28x28 image to a 1D array
    Dense(128, activation='relu'), # Hidden layer: 128 neurons with ReLU activation
    Dense(10, activation='softmax')  # Output layer: 10 neurons (for 10 classes) with Softmax activation
])

model.summary()
print('Neural network model designed successfully.')
# Out:
# Designing the neural network model...
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_1 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │         1,290 │
# ...

# %% [markdown]
# **Reasoning**:
# The previous step successfully designed the neural network model. Now, as per the plan, I need to compile the model using an Adam optimizer, sparse_categorical_crossentropy loss function, and accuracy metric.

# %%
print('Compiling the neural network model...')
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
print('Neural network model compiled successfully.')
# Out:
# Compiling the neural network model...
# Neural network model compiled successfully.

# %% [markdown]
# ## Compile Model
#
# ### Subtask:
# Compile the neural network model with an Adam optimizer, sparse_categorical_crossentropy loss function, and accuracy metric.

# %% [markdown]
# ## Train Model
#
# ### Subtask:
# Train the compiled model using the normalized training data, with specified epochs and validation split.

# %% [markdown]
# ## Evaluate Model Performance
#
# ### Subtask:
# Evaluate the trained model on the test dataset to assess its performance in terms of loss and accuracy.

# %% [markdown]
# ## Plot Accuracy Curves
#
# ### Subtask:
# Plot the training and validation accuracy curves over epochs using the `history` object.

# %% [markdown]
# ## Make Predictions
#
# ### Subtask:
# Perform predictions on a few sample handwritten digits from the test set and display the predictions alongside the actual labels.

# %% [markdown]
# **Reasoning**:
# To demonstrate the model's predictive capability, I will randomly select 5 images from the test set. For each selected image, I'll display the image itself, the model's prediction (the digit with the highest probability), and the actual true label. This will give a visual confirmation of the model's performance.

# %% [markdown]
# **Reasoning**:
# Now that all the steps for implementing, training, and evaluating the Feed-Forward Neural Network are complete, I will provide a comprehensive summary of the entire process. This summary will cover the dataset, model architecture, training details, evaluation metrics, and the visual confirmation of predictions, fulfilling the final subtask of the plan.

# %% [markdown]
# We have successfully built and evaluated a Feed-Forward Neural Network for handwritten digit classification using the MNIST dataset.
#
# **Process Overview:**
# 1.  **Libraries Imported:** `tensorflow`, `numpy`, and `matplotlib.pyplot` were imported.
# 2.  **Dataset Loaded:** The MNIST dataset was loaded, consisting of 60,000 training images and 10,000 test images, each 28x28 pixels.
# 3.  **Data Preprocessing:** Pixel values were normalized to the range [0, 1] to aid model training.
# 4.  **Model Architecture:** A `Sequential` Keras model was designed with:
#     *   A `Flatten` layer to convert 28x28 images into a 784-pixel vector.
#     *   A `Dense` hidden layer with 128 neurons and `ReLU` activation.
#     *   A `Dense` output layer with 10 neurons (for 10 classes) and `Softmax` activation.
# 5.  **Model Compilation:** The model was compiled using the `Adam` optimizer, `sparse_categorical_crossentropy` loss function, and `accuracy` as the metric.
# 6.  **Model Training:** The model was trained for 10 epochs with a 20% validation split from the training data. The training showed continuous improvement in both training and validation accuracy.
# 7.  **Model Evaluation:** The trained model was evaluated on the unseen test dataset, achieving:
#     *   Test Loss: **{loss:.4f}**
#     *   Test Accuracy: **{accuracy:.4f}**
# 8.  **Visualization:**
#     *   Accuracy curves were plotted, demonstrating the training and validation accuracy over the epochs, indicating good learning without significant overfitting.
#     *   Sample predictions were displayed, visually confirming the model's ability to correctly classify handwritten digits.

# %% [markdown]
# ## Resources

# %% [markdown]
# **Reasoning**:
# To plot the accuracy curves, I will extract the `accuracy` and `val_accuracy` from the `history` object. Then, I will use `matplotlib.pyplot` to create a line plot, showing how both training and validation accuracy changed over the epochs. This helps in understanding if the model is overfitting or underfitting.

# %%
print('Training the neural network model...')
history = model.fit(x_train_normalized, y_train, epochs=10, validation_split=0.2)
print('Neural network model trained successfully.')
# Out:
# Training the neural network model...
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9177 - loss: 0.2901 - val_accuracy: 0.9555 - val_loss: 0.1574
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9631 - loss: 0.1276 - val_accuracy: 0.9613 - val_loss: 0.1337
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9733 - loss: 0.0893 - val_accuracy: 0.9708 - val_loss: 0.1045
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9800 - loss: 0.0655 - val_accuracy: 0.9722 - val_loss: 0.0902
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9847 - loss: 0.0495 - val_accuracy: 0.9745 - val_loss: 0.0870
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9884 - loss: 0.0385 - val_accuracy: 0.9755 - val_loss: 0.0834
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9907 - loss: 0.0302 - val_accuracy: 0.9752 - val_loss: 0.0915
# Epoch 8/10
# ...

# %%
print('Evaluating model performance...')
loss, accuracy = model.evaluate(x_test_normalized, y_test)
print(f"\nTest Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")
print('Model evaluation complete.')
# Out:
# Evaluating model performance...
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9757 - loss: 0.0860
#
# Test Loss: 0.0860
# Test Accuracy: 0.9757
# Model evaluation complete.

# %%
print('Plotting training and validation accuracy curves...')

plt.figure(figsize=(8, 5))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

print('Accuracy curves plotted successfully.')
# Out:
# Plotting training and validation accuracy curves...
# Accuracy curves plotted successfully.

# %%
print('Making predictions on sample images...')

num_predictions = 5

# Select random indices from the test set
random_indices = np.random.choice(len(x_test_normalized), num_predictions, replace=False)

plt.figure(figsize=(10, 4))
for i, idx in enumerate(random_indices):
    image = x_test_normalized[idx]
    true_label = y_test[idx]

    # The model expects a batch of images, so we add an extra dimension
    prediction = model.predict(np.expand_dims(image, axis=0))
    predicted_label = np.argmax(prediction)

    plt.subplot(1, num_predictions, i + 1)
    plt.imshow(image, cmap=plt.cm.binary)
    plt.title(f"Pred: {predicted_label}\nTrue: {true_label}")
    plt.axis('off')

plt.suptitle('Sample Predictions', y=1.05)
plt.tight_layout()
plt.show()
print('Predictions displayed successfully.')
# Out:
# Making predictions on sample images...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Predictions displayed successfully.

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# --- Function to preprocess image for MNIST model ---
def preprocess_image(image_path, threshold=0.5):
    try:
        # Open image, convert to grayscale (0=black, 255=white)
        img = Image.open(image_path).convert('L')
        img = img.resize((28, 28)) # Resize to 28x28 pixels
        img_array = np.array(img).astype('float32') / 255.0 # Normalize to 0.0-1.0 (0.0=black, 1.0=white)

        # Invert colors: MNIST has white digits on a black background (high values for digit, low for background).
        # If the input image is black digit on white background, it needs inversion.
        # We assume the user draws a dark digit on a light background.
        # So, invert the array: 0.0 (background) becomes 1.0 (digit), and 1.0 (digit) becomes 0.0 (background).
        img_array = 1.0 - img_array

        # Apply a binary threshold to make the digit more distinct (strictly black/white)
        # Pixels above threshold become 1.0 (white digit), below become 0.0 (black background)
        img_array = (img_array > threshold).astype('float32')

        # Display the preprocessed image for user verification
        plt.figure(figsize=(2, 2))
        plt.imshow(img_array, cmap=plt.cm.binary) # Display with black background, white digit
        plt.title("Preprocessed Image")
        plt.axis('off')
        plt.show()

        img_array = np.expand_dims(img_array, axis=0) # Add batch dimension for model prediction
        return img_array
    except FileNotFoundError:
        print(f"Error: Image file not found at {image_path}")
        return None
    except Exception as e:
        print(f"Error processing image: {e}")
        return None

# --- Main prediction logic ---
image_file_path = input("Enter the path to the image file for prediction: ")

preprocessed_image = preprocess_image(image_file_path)

if preprocessed_image is not None:
    print(f"Making prediction for image: {image_file_path}")
    # The model expects a batch of images, which preprocess_image already provides
    prediction_probabilities = model.predict(preprocessed_image)
    predicted_label = np.argmax(prediction_probabilities)

    print(f"Prediction complete. The model predicts the digit is: {predicted_label}")
else:
    print("Could not make prediction due to image processing error.")
# Out:
# Enter the path to the image file for prediction: /content/Screenshot 2026-07-21 112836.png
# Making prediction for image: /content/Screenshot 2026-07-21 112836.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Prediction complete. The model predicts the digit is: 5
